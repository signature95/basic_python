# %% [markdown]
# <div class="alert alert-block" style="border: 1px solid #455A64;background-color:#ECEFF1;">
# 본 자료 및 영상 컨텐츠는 저작권법 제25조 2항에 의해 보호를 받습니다. 본 컨텐츠 및 컨텐츠 일부 문구등을 외부에 공개, 게시하는 것을 금지합니다.
# </div>

# %% [markdown]
# ## Open API(Rest API)를 활용한 크롤링
#
# ### Open API(Rest API)란?
#  - **API:** Application Programming Interface의 약자로, 특정 프로그램을 만들기 위해 제공되는 모듈(함수 등)을 의미
#  - **Open API:** 공개 API라고도 불리우며, 누구나 사용할 수 있도록 공개된 API (주로 Rest API 기술을 많이 사용함)
#  - **Rest API:** Representational State Transfer API의 약자로, HTTP프로토콜을 통해 서버 제공 기능을 사용할 수 있는 함수를 의미
#    - 일반적으로 XML, JSON의 형태로 응답을 전달(원하는 데이터 추출이 수월)
#    - [참고 - RestAPI란](http://hyunalee.tistory.com/1)

# %% [markdown]
# ### JSON 이란?
#  - JavaScript Object Notation 줄임말
#  - 웹환경에서 서버와 클라이언트 사이에 데이터를 주고 받을때 많이 사용
#    - Rest API가 주요한 예제
#  - JSON 포멧 예 <br>
#  { "id":"01", "language": "Java", "edition": "third", "author": "Herbert Schildt" }
#  <br>
#  <br>
#
#  - 참고 (https://books.google.co.kr/books?id=euSiAwAAQBAJ&pg=PT1755&lpg=PT1755&dq=json+%EC%9E%A5%EC%A0%90&source=bl&ots=VjTIoOjbTK&sig=3t7MXA7g2CvEi8SyD0-GQVywzw0&hl=ko&sa=X&ved=0ahUKEwiwo8OvxJfWAhXDsJQKHYaBDpI4ChDoAQhVMAg#v=onepage&q=json%20%EC%9E%A5%EC%A0%90&f=false)
#
#  출처: http://dpug.tistory.com/67#.WbycWshJaUk [퍼그의 전초기지]

# %%
import json

data = """
{
    "id":"01","language":"Java", "edition": "third", "author": "Herbert Schildt",
    "history":
    [{
        "date": "2015-03-11",
        "item": "iPhone"
    },
    {
        "date": "2016-03-11",
        "item": "ANDROID"
    }]
}
"""
json_data = json.loads(data)
print(json_data)
print(json_data['history'])
print(json_data['history'][0])
print(json_data['history'][0]['date'])
# Out:
# {'id': '01', 'language': 'Java', 'edition': 'third', 'author': 'Herbert Schildt', 'history': [{'date': '2015-03-11', 'item': 'iPhone'}, {'date': '2016-03-11', 'item': 'ANDROID'}]}
# [{'date': '2015-03-11', 'item': 'iPhone'}, {'date': '2016-03-11', 'item': 'ANDROID'}]
# {'date': '2015-03-11', 'item': 'iPhone'}
# 2015-03-11

# %%
import json

# 네이버 쇼핑에서, '연남동' 이라는 키워드로 검색한 상품 리스트 결과
data = '''
{
    "lastBuildDate": "Fri, 20 Aug 2021 00:29:38 +0900",
    "total": 31441,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "‘34kg 나체 시신’ 피의자들 “피해자 증상 검색했고, 119 신고”… 보복살인...",
            "originallink": "http://www.segye.com/content/html/2021/08/19/20210819510180.html?OutUrl=naver",
            "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=022&aid=0003611474",
            "description": "사진=연합뉴스 안씨와 김씨는 지난 4월1일부터 6월13일까지 피해자 박모(20)씨를 서울 마포구 <b>연남동</b>의 한 오피스텔에 감금한 뒤 폭행하고 고문을 가해 폐렴, 영양실조 등으로 인한 죽음에 이르게 한 혐의를 받고 있다. 해당... ",
            "pubDate": "Thu, 19 Aug 2021 17:03:00 +0900"
        },
        {
            "title": "강재준 “고창석 아내, 2시간 동안 내 얼굴 보고 빵 터져&quot;(‘놀토’)",
            "originallink": "http://star.mk.co.kr/new/view.php?mc=ST&year=2021&no=803994",
            "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=009&aid=0004840486",
            "description": "실물은 한 번도 못 뵀는데 저희가 <b>연남동</b>에서 가게를 운영했을 때 고창석 씨의 아내 분께서 가게에 오셔서 저를 보시더니 2시간 동안 빵 터지셨다. 웃음이 안 멈추시더라”며 비하인드 스토리를 전했다. 이은형은 “문어... ",
            "pubDate": "Thu, 19 Aug 2021 15:50:00 +0900"
        },
        {
            "title": "'34㎏ 시신' 동창생들 첫 재판…&quot;보복살인 아냐&quot; 부인",
            "originallink": "http://www.newsis.com/view/?id=NISX20210819_0001553231&cID=10201&pID=10200",
            "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=003&aid=0010672377",
            "description": "김씨와 안씨는 지난 4월1일부터 6월13일까지 피해자 박모(20)씨를 서울 마포구 <b>연남동</b>의 한 오피스텔에 감금한 뒤 폭행하고 고문을 가해 폐렴, 영양실조 등으로 인한 죽음에 이르게 했다는 혐의를 받고 있다. 해당... ",
            "pubDate": "Thu, 19 Aug 2021 13:27:00 +0900"
        },
        {
            "title": "'마포 오피스텔 감금·살인' 피의자들…&quot;보복살인 아냐&quot; 혐의 부인",
            "originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=02676486629148960",
            "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=018&aid=0005014782",
            "description": "동창생 감금·협박하는 등 가혹행위…피해자 결국 숨져 앞서 지난 6월 13일 오전 마포구 <b>연남동</b>의 한 오피스텔에서 박씨가 숨진 채로 발견됐다. 검찰 조사에 따르면 안씨와 김씨는 박씨를 협박해 허위 채무변제 계약서를... ",
            "pubDate": "Thu, 19 Aug 2021 13:06:00 +0900"
        },
        {
            "title": "마포 오피스텔 '34kg 시신' 20대들, 첫 재판서 '보복목적 살인' 부인",
            "originallink": "https://www.news1.kr/articles/?4408056",
            "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005550629",
            "description": "B씨는 서울 마포구 <b>연남동</b>의 한 오피스텔에서 나체상태로 숨진 채 발견됐다. 그는 사망 당시 34㎏의 심각한 저체중에 결박된 상태였던 것으로 알려졌다. 수사과정에서 이들이 2020년 9월부터 B씨가 노트북을 파손한 것을... ",
            "pubDate": "Thu, 19 Aug 2021 12:17:00 +0900"
        },
        {
            "title": "'34㎏ 시신' 마포 오피스텔 사건 첫 재판…보복목적·고의 살인 부인할까",
            "originallink": "https://www.news1.kr/articles/?4407203",
            "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005549607",
            "description": "A씨는 서울 마포구 <b>연남동</b>의 한 오피스텔에서 나체상태로 숨진 채 발견됐다. 그는 사망 당시 34㎏의 심각한 저체중에 결박된 상태였던 것으로 알려졌다. 수사과정에서 이들이 2020년 9월부터 피해자 A씨가 노트북을 파손한... ",
            "pubDate": "Thu, 19 Aug 2021 06:20:00 +0900"
        },
        {
            "title": "벤앤제리스 아이스크림 2주년을 특별한 혜택과 함께 축하해 주세요!",
            "originallink": "http://moneys.mt.co.kr/news/mwView.php?no=2021081412358042733",
            "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=417&aid=0000726354",
            "description": "벤앤제리스는 2019년 8월 GS 25 선론칭, 같은 해 9월 <b>연남동</b>에 팝업스토어 ‘벤앤제리스 하우스’를 오픈하며 한국에 첫 선을 보였다. 밀도 높은 진한 맛에 큼직한 청크와 스월까지 더해져 진정한 ‘미국 맛’... ",
            "pubDate": "Wed, 18 Aug 2021 21:03:00 +0900"
        },
        {
            "title": "경성고 시간강사(보건) 채용.. 접수 18일까지",
            "originallink": "http://www.veritas-a.com/news/articleView.html?idxno=382283",
            "link": "http://www.veritas-a.com/news/articleView.html?idxno=382283",
            "description": "이후 1968년 마포구 <b>연남동</b>으로 이전했다. 교원수는 58명(남 29명, 여 29명)이고 학생수는 746명(남)이다. 경성고는 2018학년 대입에서 서울대등록자 1명, DGIST등록자 1명 등을 배출했다. 경성고가 시간강사(보건)를... ",
            "pubDate": "Wed, 18 Aug 2021 13:26:00 +0900"
        },
        {
            "title": "시티오씨엘 관문 상가, '스타오씨엘 에비뉴Ⅰ'… 랜드마크로 기대",
            "originallink": "http://www.woodkorea.co.kr/news/articleView.html?idxno=53919",
            "link": "http://www.woodkorea.co.kr/news/articleView.html?idxno=53919",
            "description": "해당 상가는 서울 지하철 홍대입구역 3번 출구 초역세권 인데다 <b>연남동</b> 상권으로 들어가는 시작점에 위치해 유동인구가 많고, 집객력 또한 뛰어나다. 상가의 ㎡당 공시지가는 지난 3년간('18년~'21년) 약 23.52%(1,067만원→1... ",
            "pubDate": "Wed, 18 Aug 2021 09:32:00 +0900"
        },
        {
            "title": "'옥문아들' 슈카X김프로 &quot;전원주, 연예계 주식왕&quot;→지석진·조영구·김용만은...",
            "originallink": "http://www.osen.co.kr/article/G1111636848",
            "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=106&oid=109&aid=0004458090",
            "description": "그는 <b>연남동</b>에서 젊은 여자분에게 길을 물어봤다가 많은 시민들이 몰려들어서 놀랐다고 전하며 인기를 실감한다고 말했다. 이어 슈카는 주 시청자층이 남자분들이라며 “여성 작가분들이 싸인 받으러 오는 경우가... ",
            "pubDate": "Wed, 18 Aug 2021 08:23:00 +0900"
        }
    ]
}
'''

json_data = json.loads(data)
print (json_data['items'][0]['title'])
print (json_data['items'][0]['link'])
# Out:
# ‘34kg 나체 시신’ 피의자들 “피해자 증상 검색했고, 119 신고”… 보복살인...
# https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=022&aid=0003611474

# %% [markdown]
# ### 네이버 검색 Open API를 이용한 크롤링 초간단 실습
#  - https://developers.naver.com/main/
#  - [블로그 검색 가이드 문서](https://developers.naver.com/docs/search/blog/)
#    - 네이버 Open API 이용신청 [참고](http://hnark.tistory.com/135)

# %% [markdown]
# - postman 설치 (https://www.getpostman.com/downloads/)
#   - (상세 가이드: http://www.a-mean-blog.com/ko/blog/Node-JS-API/_/API-%ED%85%8C%EC%8A%A4%ED%8A%B8-%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8-Postman-%EC%84%A4%EC%B9%98%EB%B0%8F-%EA%B0%84%EB%8B%A8-%EC%82%AC%EC%9A%A9%EB%B2%95)
#
# - 사용법
#    1. Sign Up in Postman
#    2. Insert https://openapi.naver.com/v1/search/news.json?query=스마트 into GET
#    3. Add X-Naver-Client-Id(key), <font color="blue">CsODwdUTyG9vOI1uIeIf</font>(value) into Headers
#    4. Add X-Naver-Client-Secret(key), <font color="blue">YmIx0GW8JG</font>(value) into Headers
#    5. Send
#    <img src="postman.png" />

# %% [markdown]
# - [참고: 네이버 Open API HTTP 응답 상태 에러 코드 목록1](https://developers.naver.com/docs/common/openapiguide/#/errorcode.md)
# - [참고: 일반적인 HTTP 응답 상태 코드](http://ooz.co.kr/260)

# %% [markdown]
# ### 네이버 Open API 사용하기

# %%
import requests
import pprint

client_id = 'NQ29i1a5xXPPg8Yczbfq'
client_secret = '4PQI3QSsQE'

naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=연남동&display=100'
header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
res = requests.get(naver_open_api, headers=header_params)

# res.json()

if res.status_code == 200:
    data = res.json()
    for index, item in enumerate(data['items']):
        print (index + 1, item['title'], item['link'])
    pprint.pprint(data['items'])
        
else:
    print ("Error Code:", res.status_code)
# Out:
# 1 서울 홍대 <b>연남동</b> 브라이덜 샤워 파티룸 공간 프로포즈 생일파티 대여 대관 촬영 스튜디오 https://search.shopping.naver.com/gate.nhn?id=82900760448
# 2 진푸드시스템 <b>연남동</b> 기사식당 왕돈까스 https://search.shopping.naver.com/gate.nhn?id=11308451586
# 3 홍대 <b>연남동</b> 야외 잔디테라스 루프탑 피크닉 파티룸 포넬라 https://search.shopping.naver.com/gate.nhn?id=83095287511
# 4 <b>연남동</b> 기사식당 왕돈까스 https://search.shopping.naver.com/gate.nhn?id=27717995144
# 5 스펀지밥 짱구 세일러문 토이스토리 몬스터주식회사 덤보 스티치 산리오 엘모 호빵맨 디즈니 픽사 캐릭터 40장 조각스티커 셋트 https://search.shopping.naver.com/gate.nhn?id=82680199595
# 6 <b>연남동</b>공작새 디즈니 토이스토리4 9종 엽서셋트 https://search.shopping.naver.com/gate.nhn?id=82541916312
# 7 서울 홍대 이색 프렌치 스타일 마카롱 <b>연남동</b> 원데이 클래스 https://search.shopping.naver.com/gate.nhn?id=82444133105
# 8 [생화데코]홍대 <b>연남동</b> 루프탑 파티룸 브라이덜샤워 생일파티 베이비샤워 돌 백일 촬영스튜디오 https://search.shopping.naver.com/gate.nhn?id=82502934446
# 9 <b>연남동</b> 맛집 명인갈비 숙성 돼지양념구이 1kg https://search.shopping.naver.com/gate.nhn?id=82994749220
# ...

# %%
import requests
import openpyxl

client_id = 'NQ29i1a5xXPPg8Yczbfq'
client_secret = '4PQI3QSsQE'
start, num = 1, 0

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=아이폰케이스&display=100&start=' + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num += 1
            print(num, item['title'], item['link'])
    else:
        print ("Error Code:", res.status_code)
# Out:
# 1 제로스킨 <b>아이폰</b> 12 / <b>아이폰</b> 12 프로용 판테온 투명 <b>케이스</b> https://search.shopping.naver.com/gate.nhn?id=24465514522
# 2 투명 젤리 카드 범퍼 <b>아이폰 케이스</b> 갤럭시A32 방탄 폰케이스 갤럭시 S21 울트라 https://search.shopping.naver.com/gate.nhn?id=9685179803
# 3 주파집 <b>아이폰</b> 12 / <b>아이폰</b> 12 프로용 슬림핏 <b>케이스</b> 1+1 https://search.shopping.naver.com/gate.nhn?id=24567884522
# 4 제로스킨 <b>아이폰</b> 12 프로 시그니처7 투명 <b>케이스</b> https://search.shopping.naver.com/gate.nhn?id=26405670523
# 5 슈퍼쉘 <b>아이폰</b> 12 / <b>아이폰</b> 12 프로용 에어 슬림 프로  <b>케이스</b> https://search.shopping.naver.com/gate.nhn?id=28234050522
# 6 신지모루 <b>아이폰</b> 12 / <b>아이폰</b> 12 프로용 에어로핏 슬림 <b>케이스</b> https://search.shopping.naver.com/gate.nhn?id=24475425522
# 7 제로스킨 <b>아이폰</b> SE2용 / <b>아이폰</b> 7용 / <b>아이폰</b> 8용 스키니매트 <b>케이스</b> https://search.shopping.naver.com/gate.nhn?id=11945594437
# 8 주파집 <b>아이폰</b> 12 / <b>아이폰</b> 12 프로용 실리콘 <b>케이스</b> https://search.shopping.naver.com/gate.nhn?id=24549283523
# ...

# %%
import requests
import openpyxl

client_id = 'NQ29i1a5xXPPg8Yczbfq'
client_secret = '4PQI3QSsQE'
start, num = 1, 0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions['B'].width = 40
excel_sheet.column_dimensions['C'].width = 100
excel_sheet.append(['랭킹', '제목', '링크'])

for index in range(10):
    start_number = start + (index * 100)
    naver_open_api = 'https://openapi.naver.com/v1/search/shop.json?query=아이폰케이스&display=100&start=' + str(start_number)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    if res.status_code == 200:
        data = res.json()
        for item in data['items']:
            num += 1
            excel_sheet.append([num, item['title'], item['link']])
    else:
        print ("Error Code:", res.status_code)

excel_file.save('IPHONECASE.xlsx')
excel_file.close()
